# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df=pd.get_dummies(df)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2
#
#    Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                    1                        0                       0
# 1                    1                        0                       0
# 2                    1                        0                       0
# 3                    1                        0                       0
# 4                    1                        0                       0

# %%
df.drop(columns='Id',inplace=True)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                      1                        0                       0
# ...

# %%
X=df.iloc[:,:4].values
y=df.iloc[:,4:].values

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
mdl=Sequential()
mdl.add(Dense(input_dim=4,units=8,activation='relu'))
mdl.add(Dense(units=8,activation='relu'))
mdl.add(Dense(units=16,activation='relu'))
mdl.add(Dense(units=3,activation='softmax'))

# %%
mdl.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
mdl.fit(X_train,y_train,epochs=200,batch_size=32)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0768 - accuracy: 0.9750
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 0.9750
# Epoch 3/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9750
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9750
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9750
# Epoch 6/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0752 - accuracy: 0.9750
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9750
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9750
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9750
# Epoch 10/200
# ...

# %%
mdl.evaluate(X_test,y_test)
# Out:
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0663 - accuracy: 0.9667
# [0.06625203788280487, 0.9666666388511658]
